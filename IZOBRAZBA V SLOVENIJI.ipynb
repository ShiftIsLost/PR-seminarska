# %% [markdown]
# # IZOBRAZBA V SLOVENIJI

# %% [markdown]
# Tukaj se nahaja koda za inicializacijo podatkov.

# %%
from datetime import datetime
import numpy as np
import pandas as pd
from collections import defaultdict
import matplotlib.pyplot as plt

# %%
zaposlitveni_status = pd.read_csv('podatki/delovni-aktivni-zaposlitveni-status.csv',sep=' ',encoding='mbcs')
izobrazba = pd.read_csv('podatki/delovno-aktivno-obcina-izobrazba-spol.csv',sep=' ',encoding='mbcs')
brezposlni = pd.read_csv('podatki/registrirano-brezposlni.csv',sep=' ',encoding='mbcs')

print(izobrazba)
# Out:
#                   OBÈINE 2005 Izobrazba - SKUPAJ Spol - SKUPAJ  \
# 0              SLOVENIJA                                813529
# 1             Ajdovšèina                                  7351
# 2               Beltinci                                  3348
# 3                   Bled                                  4343
# 4                 Bohinj                                  2184
# ..                   ...                                   ...
# 198  Mokronog - Trebelno                                     -
# 199             Poljèane                                     -
# 200      Renèe - Vogrsko                                     -
# 201    Središèe ob Dravi                                     -
# 202               Straža                                     -
#
#     2005 Izobrazba - SKUPAJ Moški 2005 Izobrazba - SKUPAJ Ženske  \
# 0                          454704                         358825
# 1                            4298                           3052
# ...

# %% [markdown]
# Vprasanje 1
