# %% [markdown]
# # IZOBRAZBA V SLOVENIJI

# %% [markdown]
# Tukaj se nahaja koda za inicializacijo podatkov.

# %%
from datetime import datetime
import numpy as np
import pandas as pd
from collections import defaultdict
import matplotlib.pyplot as plt

# %%
brezposlni = pd.read_csv('podatki/registrirano-brezposlni.csv',sep=' ',encoding='cp1250')
#Delovno aktivno prebivalstvo, registrirano brezposelne osebe in stopnje registrirane brezposelnosti po starostnih skupinah in občinah prebivališča, Slovenija, 2010M01 - 2016M12
#link: https://pxweb.stat.si/SiStatData/pxweb/sl/Data/-/0700995S.PX
brezposlni
# Out:
#          OBČINE                                MERITVE 2010M01 15-24  \
# 0     SLOVENIJA  Delovno aktivno prebivalstvo - SKUPAJ         38654
# 1     SLOVENIJA         Registrirane brezposelne osebe         12177
# 2     SLOVENIJA    Stopnja registrirane brezposelnosti          24.0
# 3    Ajdovščina  Delovno aktivno prebivalstvo - SKUPAJ           394
# 4    Ajdovščina         Registrirane brezposelne osebe            90
# ..          ...                                    ...           ...
# 634   Žirovnica         Registrirane brezposelne osebe            16
# 635   Žirovnica    Stopnja registrirane brezposelnosti          18.4
# 636   Žužemberk  Delovno aktivno prebivalstvo - SKUPAJ           106
# 637   Žužemberk         Registrirane brezposelne osebe            24
# 638   Žužemberk    Stopnja registrirane brezposelnosti          18.5
#
#     2010M01 25-29 2010M01 30-34 2010M01 35-39 2010M01 40-44 2010M01 45-49  \
# ...

# %%
zaposlitveni_status = pd.read_csv('podatki/delovni-aktivni-zaposlitveni-status.csv',sep=' ',encoding='cp1250')
#občine, meritve, mesec, starostni razred 
#link: https://pxweb.stat.si/SiStatData/pxweb/sl/Data/-/0700995S.PX
zaposlitveni_status
# Out:
#     KOHEZIJSKA REGIJA  DELOVNO AKTIVNO PREBIVALSTVO           SPOL  \
# 0           SLOVENIJA      Delovno aktivni - SKUPAJ  Spol - SKUPAJ
# 1           SLOVENIJA      Delovno aktivni - SKUPAJ          Moški
# 2           SLOVENIJA      Delovno aktivni - SKUPAJ         Ženske
# 3           SLOVENIJA               ..Samozaposleni  Spol - SKUPAJ
# 4           SLOVENIJA               ..Samozaposleni          Moški
# ..                ...                           ...            ...
# 58  Zahodna Slovenija         ....Druge oblike dela          Moški
# 59  Zahodna Slovenija         ....Druge oblike dela         Ženske
# 60  Zahodna Slovenija  ..Pomagajoči družinski člani  Spol - SKUPAJ
# 61  Zahodna Slovenija  ..Pomagajoči družinski člani          Moški
# 62  Zahodna Slovenija  ..Pomagajoči družinski člani         Ženske
#
#    Število v 1000 2008Q1 Število v 1000 2008Q2  Število v 1000 2008Q3  \
# 0                    971                   990                   1023
# ...

# %%
delovno_aktivni_izobrazba = pd.read_csv('podatki/delovno-aktivno-obcina-izobrazba-spol.csv',sep=' ',encoding='cp1250')
#občine, leto, dosežena izobrazba, spol 
#link: https://pxweb.stat.si/SiStatData/pxweb/sl/Data/-/0764721S.PX
delovno_aktivni_izobrazba
# Out:
#                           OBČINE 2005 Izobrazba - SKUPAJ Spol - SKUPAJ  \
# 0                      SLOVENIJA                                813529
# 1                     Ajdovščina                                  7351
# 2                       Beltinci                                  3348
# 3                           Bled                                  4343
# 4                         Bohinj                                  2184
# ..                           ...                                   ...
# 208            Rečica ob Savinji                                     -
# 209  Sveti Jurij v Slov. goricah                                     -
# 210                   Šentrupert                                     -
# 211                        Mirna                                     -
# 212             Ankaran/Ancarano                                     -
#
#     2005 Izobrazba - SKUPAJ Moški 2005 Izobrazba - SKUPAJ Ženske  \
# ...

# %%
izobrazba_obcina = pd.read_csv('podatki/izobrazbazevanje-po-obcinah.csv',sep=' ',encoding='cp1250')
#vrsta izobraževanja, občine, študijsko leto  
#link: https://pxweb.stat.si/SiStatData/pxweb/sl/Data/-/0955069S.px
izobrazba_obcina
# Out:
#                    VRSTA IZOBRAŽEVANJA                                 OBČINE  \
# 0         Vrsta izobraževanja - SKUPAJ                              SLOVENIJA
# 1         Vrsta izobraževanja - SKUPAJ                             Ajdovščina
# 2         Vrsta izobraževanja - SKUPAJ                       Ankaran/Ancarano
# 3         Vrsta izobraževanja - SKUPAJ                                  Apače
# 4         Vrsta izobraževanja - SKUPAJ                               Beltinci
# ...                                ...                                    ...
# 2563  Doktorsko (3. bolonjska stopnja)                                 Žetale
# 2564  Doktorsko (3. bolonjska stopnja)                                   Žiri
# 2565  Doktorsko (3. bolonjska stopnja)                              Žirovnica
# 2566  Doktorsko (3. bolonjska stopnja)                              Žužemberk
# 2567  Doktorsko (3. bolonjska stopnja)  Stalno bivališče neznano ali v tujini
#
# ...

# %%
dijaki_vrsta_izobrazbe = pd.read_csv('podatki/dijaki-vrsta-izobrazbe.csv',sep=' ',encoding='cp1250')
#Dijaki po starosti, letnikih, spolu in vrsti izobraževanja, Slovenija, letno
#Link: https://pxweb.stat.si/SiStatData/pxweb/sl/Data/-/0953221S.px
dijaki_vrsta_izobrazbe
# Out:
#               VRSTA IZOBRAŽEVANJA                LETNIK           STAROST  \
# 0    Vrsta izobraževanja - SKUPAJ  Vsi letniki - SKUPAJ  Starost - Skupaj
# 1    Vrsta izobraževanja - SKUPAJ  Vsi letniki - SKUPAJ   13 let ali manj
# 2    Vrsta izobraževanja - SKUPAJ  Vsi letniki - SKUPAJ            14 let
# 3    Vrsta izobraževanja - SKUPAJ  Vsi letniki - SKUPAJ            15 let
# 4    Vrsta izobraževanja - SKUPAJ  Vsi letniki - SKUPAJ            16 let
# ..                            ...                   ...               ...
# 595            …maturitetni tečaj             5. letnik            17 let
# 596            …maturitetni tečaj             5. letnik            18 let
# 597            …maturitetni tečaj             5. letnik            19 let
# 598            …maturitetni tečaj             5. letnik            20 let
# 599            …maturitetni tečaj             5. letnik     21 let in več
#
#     2009/10 Spol - SKUPAJ 2009/10 Moški 2009/10 Ženske 2010/11 Spol - SKUPAJ  \
# ...

# %%
os_izobrazba = pd.read_csv('podatki/os-izobrazba.csv',sep=' ',encoding='cp1250')
#Osnovne šole in učenci, vključeni v redne in prilagojene programe, po vrsti šole in občini šole, Slovenija, letno
#Link: https://pxweb.stat.si/SiStatData/pxweb/sl/Data/-/0952752S.px
os_izobrazba
# Out:
#         OBČINA ZAVODA 2000/01 Osnovne šole - SKUPAJ Učenci  \
# 0           SLOVENIJA                               183897
# 1          Ajdovščina                                 1800
# 2    Ankaran/Ancarano                                    -
# 3               Apače                                    -
# 4            Beltinci                                  733
# ..                ...                                  ...
# 208         Železniki                                  887
# 209            Žetale                                  150
# 210              Žiri                                  542
# 211         Žirovnica                                  382
# 212         Žužemberk                                  544
#
#     2000/01 Osnovne šole - SKUPAJ Šole in podružnice  \
# 0                                                873
# 1                                                 15
# 2                                                  -
# ...

# %%
prebivalstvo_po_obcinah = pd.read_csv('podatki/prebivalstvo-po-občinah.csv',sep=' ',encoding='cp1250', low_memory=False)
#Prebivalstvo po velikih in petletnih starostnih skupinah in spolu, občine, Slovenija, polletno#Link: https://pxweb.stat.si/SiStatData/pxweb/sl/Data/-/0952752S.px
#Link: https://pxweb.stat.si/SiStatData/pxweb/sl/Data/-/05C4004S.px
prebivalstvo_po_obcinah
# Out:
#               SPOL            OBČINE 1999H2 Starost - SKUPAJ 1999H2 0-14 let  \
# 0    Spol - SKUPAJ         SLOVENIJA                 1985557          325303
# 1    Spol - SKUPAJ        Ajdovščina                   17780            3132
# 2    Spol - SKUPAJ  Ankaran/Ancarano                       -               -
# 3    Spol - SKUPAJ             Apače                       -               -
# 4    Spol - SKUPAJ          Beltinci                    8529            1486
# ..             ...               ...                     ...             ...
# 634         Ženske         Železniki                    3362             706
# 635         Ženske            Žetale                     685             116
# 636         Ženske              Žiri                    2500             485
# 637         Ženske         Žirovnica                    2015             297
# 638         Ženske         Žužemberk                    2337             481
#
# ...

# %% [markdown]
# **Vprašanje 1**
# Razlike glede na izobraženost po občinah. Katera občina je najbolj izobražena(največ maturantov diplom itd.)? Kaj se zgodi če to normaliziramo glede na prebivalstvo v občini(x maturantov na y prebivalcev)? Obrazloži ugotovitve(npr. ali so občine z manj izobraženim prebivalstvom bolj kmetijsko usmerjene).
#
# Primerjaj najbolj in najmanj izobraženo občino skozi čas(rolling avg).

# %% [markdown]
# **Vprašanje 2**
# Kakšna je razlika v akademskih dosežkih med spoloma? Ali je kateri od spolov v zaostanku(vizualiziraj)? Kakšna je razlika med spoloma na posamezni stopnji izobrazbe? (mogoče še prikaz po regijah/čas)

# %% [markdown]
# TODO: Kater spol je bolj prisoten na različnih strokovnih področjih?
# S kakšnimi tematitikami se ukvarjajo ženske, s kakšnimi moški?
# Podatkov za zadnje dve vprašanji še nimamo.
